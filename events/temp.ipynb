# %%
import json
import os

def load_jsonl_data(path):
    data = []
    with open(path) as reader:
        for row in reader:
            d = json.loads(row)
            data.append(d)
    return data

# %%
data = load_jsonl_data('/inspire/hdd/project/socialsimulation/linjiayu-CZXS25120090/FYDUAN/data/events_labeled_data/bucket_id=2/events_raw.jsonl')

data[0]
# Out:
# {'user_name': 'Roberto Kusabbi',
#  'user_id': '18878629',
#  'created_at': '2023-09-01 15:52:55',
#  'unix_timestamp': '1693554775',
#  'tweet_id': '1697517877845262463',
#  'tweet_text': 'Also don’t have a problem loaning Regi to United. I doubt it’s much of a strengthen and if it is, more likely he impacts the teams around us by playing well. Imagine a lot more PL teams loan and sell to each other in future because market is dead outside of Saudi and 4-5 clubs',
#  'bucket_id': 'bucket_id=2',
#  'tweet_time': '2023-09-01 15:52:55',
#  'event': {'time': '2023-09-01 15:52:55',
#   'location': None,
#   'environment': None,
#   'action': 'I consider loaning Regi to United.',
#   'observation': 'I doubt it’s much of a strengthen and believe he might impact the teams around us by playing well.',
#   'inner_thought': 'I imagine a lot more PL teams loan and sell to each other in the future because the market is dead outside of Saudi and 4-5 clubs.'},
#  'error': None}
